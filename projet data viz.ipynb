# %%
#Impoertation des librairies 

import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import plotly.express as px
from plotly.offline import plot
df=pd.read_excel("Global Superstore.xls")
df
# Out:
#               Order_ID Order_Date  Ship_Date       Ship_Mode Customer_ID  \
# 0       CA-2012-124891 2012-07-31 2012-07-31        Same Day    RH-19495
# 1        IN-2013-77878 2013-02-05 2013-02-07    Second Class    JR-16210
# 2        IN-2013-71249 2013-10-17 2013-10-18     First Class    CR-12730
# 3      ES-2013-1579342 2013-01-28 2013-01-30     First Class    KM-16375
# 4         SG-2013-4320 2013-11-05 2013-11-06        Same Day     RH-9495
# ...                ...        ...        ...             ...         ...
# 51285    IN-2014-62366 2014-06-19 2014-06-19        Same Day    KE-16420
# 51286   US-2014-102288 2014-06-20 2014-06-24  Standard Class    ZC-21910
# 51287   US-2013-155768 2013-12-02 2013-12-02        Same Day    LB-16795
# 51288   MX-2012-140767 2012-02-18 2012-02-22  Standard Class    RB-19795
# 51289   MX-2012-134460 2012-05-22 2012-05-26    Second Class    MC-18100
#
#           Customer_Name      Segment           City            State  \
# 0           Rick Hansen     Consumer  New York City         New York
# 1         Justin Ritter    Corporate     Wollongong  New South Wales
# 2          Craig Reiter     Consumer       Brisbane       Queensland
# 3      Katherine Murray  Home Office         Berlin           Berlin
# 4           Rick Hansen     Consumer          Dakar            Dakar
# ...                 ...          ...            ...              ...
# 51285   Katrina Edelman    Corporate           Kure        Hiroshima
# 51286  Zuschuss Carroll     Consumer        Houston            Texas
# 51287    Laurel Beltran  Home Office         Oxnard       California
# 51288        Ross Baird  Home Office       Valinhos        São Paulo
# 51289     Mick Crebagga     Consumer       Tipitapa          Managua
#
#              Country  ...        Product ID         Category Sub-Category  \
# 0      United States  ...   TEC-AC-10003033       Technology  Accessories
# 1          Australia  ...   FUR-CH-10003950        Furniture       Chairs
# 2          Australia  ...   TEC-PH-10004664       Technology       Phones
# 3            Germany  ...   TEC-PH-10004583       Technology       Phones
# 4            Senegal  ...  TEC-SHA-10000501       Technology      Copiers
# ...              ...  ...               ...              ...          ...
# 51285          Japan  ...   OFF-FA-10000746  Office Supplies    Fasteners
# 51286  United States  ...   OFF-AP-10002906  Office Supplies   Appliances
# 51287  United States  ...   OFF-EN-10001219  Office Supplies    Envelopes
# 51288         Brazil  ...   OFF-BI-10000806  Office Supplies      Binders
# 51289      Nicaragua  ...   OFF-PA-10004155  Office Supplies        Paper
#
#                                             Product Name     Sales Quantity  \
# 0      Plantronics CS510 - Over-the-Head monaural Wir...  2309.650        7
# 1              Novimex Executive Leather Armchair, Black  3709.395        9
# 2                      Nokia Smart Phone, with Caller ID  5175.171        9
# 3                         Motorola Smart Phone, Cordless  2892.510        5
# 4                         Sharp Wireless Fax, High-Speed  2832.960        8
# ...                                                  ...       ...      ...
# 51285                      Advantus Thumb Tacks, 12 Pack    65.100        5
# 51286  Hoover Replacement Belt for Commercial Guardsm...     0.444        1
# 51287       #10- 4 1/8" x 9 1/2" Security-Tint Envelopes    22.920        3
# 51288                            Acco Index Tab, Economy    13.440        2
# 51289            Eaton Computer Printout Paper, 8.5 x 11    61.380        3
#
#       Discount    Profit  Shipping Cost  Order Priority
# 0          0.0  762.1845        933.570        Critical
# 1          0.1 -288.7650        923.630        Critical
# 2          0.1  919.9710        915.490          Medium
# 3          0.1  -96.5400        910.160          Medium
# 4          0.0  311.5200        903.040        Critical
# ...        ...       ...            ...             ...
# 51285      0.0    4.5000          0.010          Medium
# 51286      0.8   -1.1100          0.010          Medium
# 51287      0.0   11.2308          0.010            High
# 51288      0.0    2.4000          0.003          Medium
# 51289      0.0    1.8000          0.002            High
#
# [51290 rows x 23 columns]

# %%
df.isnull().sum()
# Out:
# Order_ID              0
# Order_Date            0
# Ship_Date             0
# Ship_Mode             0
# Customer_ID           0
# Customer_Name         0
# Segment               0
# City                  0
# State                 0
# Country               0
# Postal Code       41296
# Market                0
# Region                0
# Product ID            0
# Category              0
# Sub-Category          0
# Product Name          0
# Sales                 0
# Quantity              0
# Discount              0
# Profit                0
# Shipping Cost         0
# Order Priority        0
# dtype: int64

# %%
df.dtypes
# Out:
# Order_ID                  object
# Order_Date        datetime64[ns]
# Ship_Date         datetime64[ns]
# Ship_Mode                 object
# Customer_ID               object
# Customer_Name             object
# Segment                   object
# City                      object
# State                     object
# Country                   object
# Postal Code              float64
# Market                    object
# Region                    object
# Product ID                object
# Category                  object
# Sub-Category              object
# Product Name              object
# Sales                    float64
# Quantity                   int64
# Discount                 float64
# Profit                   float64
# Shipping Cost            float64
# Order Priority            object
# dtype: object

# %%
df['year'] = df['Order_Date'].dt.year
df
# Out:
#               Order_ID Order_Date  Ship_Date       Ship_Mode Customer_ID  \
# 0       CA-2012-124891 2012-07-31 2012-07-31        Same Day    RH-19495
# 1        IN-2013-77878 2013-02-05 2013-02-07    Second Class    JR-16210
# 2        IN-2013-71249 2013-10-17 2013-10-18     First Class    CR-12730
# 3      ES-2013-1579342 2013-01-28 2013-01-30     First Class    KM-16375
# 4         SG-2013-4320 2013-11-05 2013-11-06        Same Day     RH-9495
# ...                ...        ...        ...             ...         ...
# 51285    IN-2014-62366 2014-06-19 2014-06-19        Same Day    KE-16420
# 51286   US-2014-102288 2014-06-20 2014-06-24  Standard Class    ZC-21910
# 51287   US-2013-155768 2013-12-02 2013-12-02        Same Day    LB-16795
# 51288   MX-2012-140767 2012-02-18 2012-02-22  Standard Class    RB-19795
# 51289   MX-2012-134460 2012-05-22 2012-05-26    Second Class    MC-18100
#
#           Customer_Name      Segment           City            State  \
# 0           Rick Hansen     Consumer  New York City         New York
# 1         Justin Ritter    Corporate     Wollongong  New South Wales
# 2          Craig Reiter     Consumer       Brisbane       Queensland
# 3      Katherine Murray  Home Office         Berlin           Berlin
# 4           Rick Hansen     Consumer          Dakar            Dakar
# ...                 ...          ...            ...              ...
# 51285   Katrina Edelman    Corporate           Kure        Hiroshima
# 51286  Zuschuss Carroll     Consumer        Houston            Texas
# 51287    Laurel Beltran  Home Office         Oxnard       California
# 51288        Ross Baird  Home Office       Valinhos        São Paulo
# 51289     Mick Crebagga     Consumer       Tipitapa          Managua
#
#              Country  ...         Category Sub-Category  \
# 0      United States  ...       Technology  Accessories
# 1          Australia  ...        Furniture       Chairs
# 2          Australia  ...       Technology       Phones
# 3            Germany  ...       Technology       Phones
# 4            Senegal  ...       Technology      Copiers
# ...              ...  ...              ...          ...
# 51285          Japan  ...  Office Supplies    Fasteners
# 51286  United States  ...  Office Supplies   Appliances
# 51287  United States  ...  Office Supplies    Envelopes
# 51288         Brazil  ...  Office Supplies      Binders
# 51289      Nicaragua  ...  Office Supplies        Paper
#
#                                             Product Name     Sales Quantity  \
# 0      Plantronics CS510 - Over-the-Head monaural Wir...  2309.650        7
# 1              Novimex Executive Leather Armchair, Black  3709.395        9
# 2                      Nokia Smart Phone, with Caller ID  5175.171        9
# 3                         Motorola Smart Phone, Cordless  2892.510        5
# 4                         Sharp Wireless Fax, High-Speed  2832.960        8
# ...                                                  ...       ...      ...
# 51285                      Advantus Thumb Tacks, 12 Pack    65.100        5
# 51286  Hoover Replacement Belt for Commercial Guardsm...     0.444        1
# 51287       #10- 4 1/8" x 9 1/2" Security-Tint Envelopes    22.920        3
# 51288                            Acco Index Tab, Economy    13.440        2
# 51289            Eaton Computer Printout Paper, 8.5 x 11    61.380        3
#
#       Discount    Profit  Shipping Cost  Order Priority  year
# 0          0.0  762.1845        933.570        Critical  2012
# 1          0.1 -288.7650        923.630        Critical  2013
# 2          0.1  919.9710        915.490          Medium  2013
# 3          0.1  -96.5400        910.160          Medium  2013
# 4          0.0  311.5200        903.040        Critical  2013
# ...        ...       ...            ...             ...   ...
# 51285      0.0    4.5000          0.010          Medium  2014
# 51286      0.8   -1.1100          0.010          Medium  2014
# 51287      0.0   11.2308          0.010            High  2013
# 51288      0.0    2.4000          0.003          Medium  2012
# 51289      0.0    1.8000          0.002            High  2012
#
# [51290 rows x 24 columns]

# %%
y=df.groupby('year')['Sales'].sum()
y
# Out:
# year
# 2011    2.259451e+06
# 2012    2.677439e+06
# 2013    3.405746e+06
# 2014    4.299866e+06
# Name: Sales, dtype: float64

# %%
x=range(2011,2015)
plt.bar(x,y,color ='maroon')
plt.xlabel("Année")
plt.ylabel("Chiffre d'affaire")
plt.title("l'évolution des ventes par année")
plt.show()

# %%
fig=px.treemap(df,path=['Country'],values='Sales')
plot(fig)
# Out:
# 'temp-plot.html'

# %%
x=df.groupby('Country')['Sales'].sum()
x
# Out:
# Country
# Afghanistan    21673.32000
# Albania         3888.12000
# Algeria        36091.59000
# Angola         25554.00000
# Argentina      57511.78328
#                   ...
# Venezuela      26587.82956
# Vietnam        65800.19940
# Yemen           2465.71200
# Zambia         26035.50000
# Zimbabwe        3765.10500
# Name: Sales, Length: 147, dtype: float64

# %%
df['CA'] = df['Country'].map(x) 
df
# Out:
#               Order_ID Order_Date  Ship_Date       Ship_Mode Customer_ID  \
# 0       CA-2012-124891 2012-07-31 2012-07-31        Same Day    RH-19495
# 1        IN-2013-77878 2013-02-05 2013-02-07    Second Class    JR-16210
# 2        IN-2013-71249 2013-10-17 2013-10-18     First Class    CR-12730
# 3      ES-2013-1579342 2013-01-28 2013-01-30     First Class    KM-16375
# 4         SG-2013-4320 2013-11-05 2013-11-06        Same Day     RH-9495
# ...                ...        ...        ...             ...         ...
# 51285    IN-2014-62366 2014-06-19 2014-06-19        Same Day    KE-16420
# 51286   US-2014-102288 2014-06-20 2014-06-24  Standard Class    ZC-21910
# 51287   US-2013-155768 2013-12-02 2013-12-02        Same Day    LB-16795
# 51288   MX-2012-140767 2012-02-18 2012-02-22  Standard Class    RB-19795
# 51289   MX-2012-134460 2012-05-22 2012-05-26    Second Class    MC-18100
#
#           Customer_Name      Segment           City            State  \
# 0           Rick Hansen     Consumer  New York City         New York
# 1         Justin Ritter    Corporate     Wollongong  New South Wales
# 2          Craig Reiter     Consumer       Brisbane       Queensland
# 3      Katherine Murray  Home Office         Berlin           Berlin
# 4           Rick Hansen     Consumer          Dakar            Dakar
# ...                 ...          ...            ...              ...
# 51285   Katrina Edelman    Corporate           Kure        Hiroshima
# 51286  Zuschuss Carroll     Consumer        Houston            Texas
# 51287    Laurel Beltran  Home Office         Oxnard       California
# 51288        Ross Baird  Home Office       Valinhos        São Paulo
# 51289     Mick Crebagga     Consumer       Tipitapa          Managua
#
#              Country  ...  Sub-Category  \
# 0      United States  ...   Accessories
# 1          Australia  ...        Chairs
# 2          Australia  ...        Phones
# 3            Germany  ...        Phones
# 4            Senegal  ...       Copiers
# ...              ...  ...           ...
# 51285          Japan  ...     Fasteners
# 51286  United States  ...    Appliances
# 51287  United States  ...     Envelopes
# 51288         Brazil  ...       Binders
# 51289      Nicaragua  ...         Paper
#
#                                             Product Name     Sales Quantity  \
# 0      Plantronics CS510 - Over-the-Head monaural Wir...  2309.650        7
# 1              Novimex Executive Leather Armchair, Black  3709.395        9
# 2                      Nokia Smart Phone, with Caller ID  5175.171        9
# 3                         Motorola Smart Phone, Cordless  2892.510        5
# 4                         Sharp Wireless Fax, High-Speed  2832.960        8
# ...                                                  ...       ...      ...
# 51285                      Advantus Thumb Tacks, 12 Pack    65.100        5
# 51286  Hoover Replacement Belt for Commercial Guardsm...     0.444        1
# 51287       #10- 4 1/8" x 9 1/2" Security-Tint Envelopes    22.920        3
# 51288                            Acco Index Tab, Economy    13.440        2
# 51289            Eaton Computer Printout Paper, 8.5 x 11    61.380        3
#
#       Discount    Profit Shipping Cost  Order Priority  year            CA
# 0          0.0  762.1845       933.570        Critical  2012  2.297201e+06
# 1          0.1 -288.7650       923.630        Critical  2013  9.252359e+05
# 2          0.1  919.9710       915.490          Medium  2013  9.252359e+05
# 3          0.1  -96.5400       910.160          Medium  2013  6.288400e+05
# 4          0.0  311.5200       903.040        Critical  2013  2.884890e+04
# ...        ...       ...           ...             ...   ...           ...
# 51285      0.0    4.5000         0.010          Medium  2014  1.007875e+05
# 51286      0.8   -1.1100         0.010          Medium  2014  2.297201e+06
# 51287      0.0   11.2308         0.010            High  2013  2.297201e+06
# 51288      0.0    2.4000         0.003          Medium  2012  3.611064e+05
# 51289      0.0    1.8000         0.002            High  2012  1.496871e+05
#
# [51290 rows x 25 columns]

# %%
y=df.groupby('year')['Sales'].sum()
df['CA_ann'] = df['year'].map(y) 
df
# Out:
#               Order_ID Order_Date  Ship_Date       Ship_Mode Customer_ID  \
# 0       CA-2012-124891 2012-07-31 2012-07-31        Same Day    RH-19495
# 1        IN-2013-77878 2013-02-05 2013-02-07    Second Class    JR-16210
# 2        IN-2013-71249 2013-10-17 2013-10-18     First Class    CR-12730
# 3      ES-2013-1579342 2013-01-28 2013-01-30     First Class    KM-16375
# 4         SG-2013-4320 2013-11-05 2013-11-06        Same Day     RH-9495
# ...                ...        ...        ...             ...         ...
# 51285    IN-2014-62366 2014-06-19 2014-06-19        Same Day    KE-16420
# 51286   US-2014-102288 2014-06-20 2014-06-24  Standard Class    ZC-21910
# 51287   US-2013-155768 2013-12-02 2013-12-02        Same Day    LB-16795
# 51288   MX-2012-140767 2012-02-18 2012-02-22  Standard Class    RB-19795
# 51289   MX-2012-134460 2012-05-22 2012-05-26    Second Class    MC-18100
#
#           Customer_Name      Segment           City            State  \
# 0           Rick Hansen     Consumer  New York City         New York
# 1         Justin Ritter    Corporate     Wollongong  New South Wales
# 2          Craig Reiter     Consumer       Brisbane       Queensland
# 3      Katherine Murray  Home Office         Berlin           Berlin
# 4           Rick Hansen     Consumer          Dakar            Dakar
# ...                 ...          ...            ...              ...
# 51285   Katrina Edelman    Corporate           Kure        Hiroshima
# 51286  Zuschuss Carroll     Consumer        Houston            Texas
# 51287    Laurel Beltran  Home Office         Oxnard       California
# 51288        Ross Baird  Home Office       Valinhos        São Paulo
# 51289     Mick Crebagga     Consumer       Tipitapa          Managua
#
#              Country  ...                                       Product Name  \
# 0      United States  ...  Plantronics CS510 - Over-the-Head monaural Wir...
# 1          Australia  ...          Novimex Executive Leather Armchair, Black
# 2          Australia  ...                  Nokia Smart Phone, with Caller ID
# 3            Germany  ...                     Motorola Smart Phone, Cordless
# 4            Senegal  ...                     Sharp Wireless Fax, High-Speed
# ...              ...  ...                                                ...
# 51285          Japan  ...                      Advantus Thumb Tacks, 12 Pack
# 51286  United States  ...  Hoover Replacement Belt for Commercial Guardsm...
# 51287  United States  ...       #10- 4 1/8" x 9 1/2" Security-Tint Envelopes
# 51288         Brazil  ...                            Acco Index Tab, Economy
# 51289      Nicaragua  ...            Eaton Computer Printout Paper, 8.5 x 11
#
#           Sales Quantity Discount    Profit Shipping Cost Order Priority  \
# 0      2309.650        7      0.0  762.1845       933.570       Critical
# 1      3709.395        9      0.1 -288.7650       923.630       Critical
# 2      5175.171        9      0.1  919.9710       915.490         Medium
# 3      2892.510        5      0.1  -96.5400       910.160         Medium
# 4      2832.960        8      0.0  311.5200       903.040       Critical
# ...         ...      ...      ...       ...           ...            ...
# 51285    65.100        5      0.0    4.5000         0.010         Medium
# 51286     0.444        1      0.8   -1.1100         0.010         Medium
# 51287    22.920        3      0.0   11.2308         0.010           High
# 51288    13.440        2      0.0    2.4000         0.003         Medium
# 51289    61.380        3      0.0    1.8000         0.002           High
#
#        year            CA        CA_ann
# 0      2012  2.297201e+06  2.677439e+06
# 1      2013  9.252359e+05  3.405746e+06
# 2      2013  9.252359e+05  3.405746e+06
# 3      2013  6.288400e+05  3.405746e+06
# 4      2013  2.884890e+04  3.405746e+06
# ...     ...           ...           ...
# 51285  2014  1.007875e+05  4.299866e+06
# 51286  2014  2.297201e+06  4.299866e+06
# 51287  2013  2.297201e+06  3.405746e+06
# 51288  2012  3.611064e+05  2.677439e+06
# 51289  2012  1.496871e+05  2.677439e+06
#
# [51290 rows x 26 columns]

# %%
y=df.groupby(['year','Country'])['Sales'].sum()
y
# Out:
# year  Country
# 2011  Afghanistan     1729.41000
#       Albania         1707.54000
#       Algeria         8539.80000
#       Angola          6416.91000
#       Argentina       8739.30512
#                         ...
# 2014  Venezuela      10059.60312
#       Vietnam        19246.86390
#       Yemen            448.71300
#       Zambia          5398.62000
#       Zimbabwe        1440.88200
# Name: Sales, Length: 537, dtype: float64

# %%
fig=px.treemap(df,path=['year','Country'],values='Sales')
plot(fig)
# Out:
# 'temp-plot.html'

# %%
fig=px.treemap(df,path=['Country'],values='Profit')
plot(fig)
# Out:
# 'temp-plot.html'

# %% [markdown]
# # Etude statistique

# %%
sns.violinplot(x=df.groupby('Country')['Sales'].sum(),color='#01D758',inner='box').set(title='Statistiques du Chiffre d_affaire')
# Out:
# [Text(0.5, 1.0, 'Statistiques du Chiffre d_affaire')]

# %%
sns.violinplot(x=df.groupby('Country')['Sales'].sum(),color='#048B9A',inner='quartile').set(title='Quartile de chiffre d_affaire')
# Out:
# [Text(0.5, 1.0, 'Quartile de chiffre d_affaire')]

# %%
sns.boxplot(y=df.groupby('Country')['Sales'].sum(),color='#FFCF39').set(title='Boxplot de chiffre d_affaire')
# Out:
# [Text(0.5, 1.0, 'Boxplot de chiffre d_affaire')]

# %%
sns.boxplot(x=df.groupby('Region')['Sales'].sum().index,y=df.groupby('Region')['Sales'].sum()).set(title='statistiques de chiffre d_affaire par region')
# Out:
# [Text(0.5, 1.0, 'statistiques de chiffre d_affaire par region')]

# %%
x=df.groupby('Country')['Profit'].sum()
x
df['Profit_pays'] = df['Country'].map(x) 
df
# Out:
#               Order_ID Order_Date  Ship_Date       Ship_Mode Customer_ID  \
# 0       CA-2012-124891 2012-07-31 2012-07-31        Same Day    RH-19495
# 1        IN-2013-77878 2013-02-05 2013-02-07    Second Class    JR-16210
# 2        IN-2013-71249 2013-10-17 2013-10-18     First Class    CR-12730
# 3      ES-2013-1579342 2013-01-28 2013-01-30     First Class    KM-16375
# 4         SG-2013-4320 2013-11-05 2013-11-06        Same Day     RH-9495
# ...                ...        ...        ...             ...         ...
# 51285    IN-2014-62366 2014-06-19 2014-06-19        Same Day    KE-16420
# 51286   US-2014-102288 2014-06-20 2014-06-24  Standard Class    ZC-21910
# 51287   US-2013-155768 2013-12-02 2013-12-02        Same Day    LB-16795
# 51288   MX-2012-140767 2012-02-18 2012-02-22  Standard Class    RB-19795
# 51289   MX-2012-134460 2012-05-22 2012-05-26    Second Class    MC-18100
#
#           Customer_Name      Segment           City            State  \
# 0           Rick Hansen     Consumer  New York City         New York
# 1         Justin Ritter    Corporate     Wollongong  New South Wales
# 2          Craig Reiter     Consumer       Brisbane       Queensland
# 3      Katherine Murray  Home Office         Berlin           Berlin
# 4           Rick Hansen     Consumer          Dakar            Dakar
# ...                 ...          ...            ...              ...
# 51285   Katrina Edelman    Corporate           Kure        Hiroshima
# 51286  Zuschuss Carroll     Consumer        Houston            Texas
# 51287    Laurel Beltran  Home Office         Oxnard       California
# 51288        Ross Baird  Home Office       Valinhos        São Paulo
# 51289     Mick Crebagga     Consumer       Tipitapa          Managua
#
#              Country  ...     Sales Quantity Discount    Profit Shipping Cost  \
# 0      United States  ...  2309.650        7      0.0  762.1845       933.570
# 1          Australia  ...  3709.395        9      0.1 -288.7650       923.630
# 2          Australia  ...  5175.171        9      0.1  919.9710       915.490
# 3            Germany  ...  2892.510        5      0.1  -96.5400       910.160
# 4            Senegal  ...  2832.960        8      0.0  311.5200       903.040
# ...              ...  ...       ...      ...      ...       ...           ...
# 51285          Japan  ...    65.100        5      0.0    4.5000         0.010
# 51286  United States  ...     0.444        1      0.8   -1.1100         0.010
# 51287  United States  ...    22.920        3      0.0   11.2308         0.010
# 51288         Brazil  ...    13.440        2      0.0    2.4000         0.003
# 51289      Nicaragua  ...    61.380        3      0.0    1.8000         0.002
#
#       Order Priority  year            CA        CA_ann   Profit_pays
# 0           Critical  2012  2.297201e+06  2.677439e+06  286397.02170
# 1           Critical  2013  9.252359e+05  3.405746e+06  103907.43300
# 2             Medium  2013  9.252359e+05  3.405746e+06  103907.43300
# 3             Medium  2013  6.288400e+05  3.405746e+06  107322.82050
# 4           Critical  2013  2.884890e+04  3.405746e+06    7511.16000
# ...              ...   ...           ...           ...           ...
# 51285         Medium  2014  1.007875e+05  4.299866e+06   24328.46700
# 51286         Medium  2014  2.297201e+06  4.299866e+06  286397.02170
# 51287           High  2013  2.297201e+06  3.405746e+06  286397.02170
# 51288         Medium  2012  3.611064e+05  2.677439e+06   30090.49896
# 51289           High  2012  1.496871e+05  2.677439e+06   33401.44456
#
# [51290 rows x 27 columns]

# %%
sns.violinplot(x=df.groupby('Country')['Profit'].sum(),color='#F3D617',inner='box').set(title='Statistiques du Profit par pays')
# Out:
# [Text(0.5, 1.0, 'Statistiques du Profit par pays')]

# %%
sns.violinplot(x=df.groupby('Country')['Profit'].sum(),color='#D473D4',inner='quartile').set(title='Quartile du Profit')
# Out:
# [Text(0.5, 1.0, 'Quartile du Profit')]

# %%
sns.boxplot(y=df.groupby('Country')['Profit'].sum(),color='#4B0082').set(title='Boxplot de Profit')
# Out:
# [Text(0.5, 1.0, 'Boxplot de Profit')]

# %%
sns.lmplot(x="CA",y="Profit_pays",data=df,markers="<").set(title='Relation entre chiffre d_affaire et le profit ')

# %%
df.groupby('Country')['Discount'].sum()
# Out:
# Country
# Afghanistan      0.000
# Albania          0.000
# Algeria          0.000
# Angola           0.000
# Argentina      168.952
#                 ...
# Venezuela       79.426
# Vietnam         63.450
# Yemen           21.000
# Zambia           0.000
# Zimbabwe        56.000
# Name: Discount, Length: 147, dtype: float64

# %%
x=df.groupby('Country')['Discount'].sum()
x
df['Discount_pays'] = df['Country'].map(x) 
df
# Out:
#               Order_ID Order_Date  Ship_Date       Ship_Mode Customer_ID  \
# 0       CA-2012-124891 2012-07-31 2012-07-31        Same Day    RH-19495
# 1        IN-2013-77878 2013-02-05 2013-02-07    Second Class    JR-16210
# 2        IN-2013-71249 2013-10-17 2013-10-18     First Class    CR-12730
# 3      ES-2013-1579342 2013-01-28 2013-01-30     First Class    KM-16375
# 4         SG-2013-4320 2013-11-05 2013-11-06        Same Day     RH-9495
# ...                ...        ...        ...             ...         ...
# 51285    IN-2014-62366 2014-06-19 2014-06-19        Same Day    KE-16420
# 51286   US-2014-102288 2014-06-20 2014-06-24  Standard Class    ZC-21910
# 51287   US-2013-155768 2013-12-02 2013-12-02        Same Day    LB-16795
# 51288   MX-2012-140767 2012-02-18 2012-02-22  Standard Class    RB-19795
# 51289   MX-2012-134460 2012-05-22 2012-05-26    Second Class    MC-18100
#
#           Customer_Name      Segment           City            State  \
# 0           Rick Hansen     Consumer  New York City         New York
# 1         Justin Ritter    Corporate     Wollongong  New South Wales
# 2          Craig Reiter     Consumer       Brisbane       Queensland
# 3      Katherine Murray  Home Office         Berlin           Berlin
# 4           Rick Hansen     Consumer          Dakar            Dakar
# ...                 ...          ...            ...              ...
# 51285   Katrina Edelman    Corporate           Kure        Hiroshima
# 51286  Zuschuss Carroll     Consumer        Houston            Texas
# 51287    Laurel Beltran  Home Office         Oxnard       California
# 51288        Ross Baird  Home Office       Valinhos        São Paulo
# 51289     Mick Crebagga     Consumer       Tipitapa          Managua
#
#              Country  ...  Quantity Discount    Profit Shipping Cost  \
# 0      United States  ...         7      0.0  762.1845       933.570
# 1          Australia  ...         9      0.1 -288.7650       923.630
# 2          Australia  ...         9      0.1  919.9710       915.490
# 3            Germany  ...         5      0.1  -96.5400       910.160
# 4            Senegal  ...         8      0.0  311.5200       903.040
# ...              ...  ...       ...      ...       ...           ...
# 51285          Japan  ...         5      0.0    4.5000         0.010
# 51286  United States  ...         1      0.8   -1.1100         0.010
# 51287  United States  ...         3      0.0   11.2308         0.010
# 51288         Brazil  ...         2      0.0    2.4000         0.003
# 51289      Nicaragua  ...         3      0.0    1.8000         0.002
#
#       Order Priority  year            CA        CA_ann   Profit_pays  \
# 0           Critical  2012  2.297201e+06  2.677439e+06  286397.02170
# 1           Critical  2013  9.252359e+05  3.405746e+06  103907.43300
# 2             Medium  2013  9.252359e+05  3.405746e+06  103907.43300
# 3             Medium  2013  6.288400e+05  3.405746e+06  107322.82050
# 4           Critical  2013  2.884890e+04  3.405746e+06    7511.16000
# ...              ...   ...           ...           ...           ...
# 51285         Medium  2014  1.007875e+05  4.299866e+06   24328.46700
# 51286         Medium  2014  2.297201e+06  4.299866e+06  286397.02170
# 51287           High  2013  2.297201e+06  3.405746e+06  286397.02170
# 51288         Medium  2012  3.611064e+05  2.677439e+06   30090.49896
# 51289           High  2012  1.496871e+05  2.677439e+06   33401.44456
#
#        Discount_pays
# 0           1561.090
# 1            407.200
# 2            407.200
# 3            117.800
# 4              0.000
# ...              ...
# 51285          8.600
# 51286       1561.090
# 51287       1561.090
# 51288        232.822
# 51289          1.270
#
# [51290 rows x 28 columns]

# %%
sns.lmplot(x="Profit_pays",y="Discount_pays",data=df,markers="d").set(title='Relation entre le Profit et le Discount')

# %%
df.groupby('Country')['Country'].count()
# Out:
# Country
# Afghanistan     55
# Albania         16
# Algeria        196
# Angola         122
# Argentina      390
#               ...
# Venezuela      194
# Vietnam        265
# Yemen           30
# Zambia         102
# Zimbabwe        80
# Name: Country, Length: 147, dtype: int64

# %%
x=df.groupby('Country')['Country'].count()
x
df['N_Order'] = df['Country'].map(x) 
df
# Out:
#               Order_ID Order_Date  Ship_Date       Ship_Mode Customer_ID  \
# 0       CA-2012-124891 2012-07-31 2012-07-31        Same Day    RH-19495
# 1        IN-2013-77878 2013-02-05 2013-02-07    Second Class    JR-16210
# 2        IN-2013-71249 2013-10-17 2013-10-18     First Class    CR-12730
# 3      ES-2013-1579342 2013-01-28 2013-01-30     First Class    KM-16375
# 4         SG-2013-4320 2013-11-05 2013-11-06        Same Day     RH-9495
# ...                ...        ...        ...             ...         ...
# 51285    IN-2014-62366 2014-06-19 2014-06-19        Same Day    KE-16420
# 51286   US-2014-102288 2014-06-20 2014-06-24  Standard Class    ZC-21910
# 51287   US-2013-155768 2013-12-02 2013-12-02        Same Day    LB-16795
# 51288   MX-2012-140767 2012-02-18 2012-02-22  Standard Class    RB-19795
# 51289   MX-2012-134460 2012-05-22 2012-05-26    Second Class    MC-18100
#
#           Customer_Name      Segment           City            State  \
# 0           Rick Hansen     Consumer  New York City         New York
# 1         Justin Ritter    Corporate     Wollongong  New South Wales
# 2          Craig Reiter     Consumer       Brisbane       Queensland
# 3      Katherine Murray  Home Office         Berlin           Berlin
# 4           Rick Hansen     Consumer          Dakar            Dakar
# ...                 ...          ...            ...              ...
# 51285   Katrina Edelman    Corporate           Kure        Hiroshima
# 51286  Zuschuss Carroll     Consumer        Houston            Texas
# 51287    Laurel Beltran  Home Office         Oxnard       California
# 51288        Ross Baird  Home Office       Valinhos        São Paulo
# 51289     Mick Crebagga     Consumer       Tipitapa          Managua
#
#              Country  ...  Sub-Category  \
# 0      United States  ...   Accessories
# 1          Australia  ...        Chairs
# 2          Australia  ...        Phones
# 3            Germany  ...        Phones
# 4            Senegal  ...       Copiers
# ...              ...  ...           ...
# 51285          Japan  ...     Fasteners
# 51286  United States  ...    Appliances
# 51287  United States  ...     Envelopes
# 51288         Brazil  ...       Binders
# 51289      Nicaragua  ...         Paper
#
#                                             Product Name     Sales Quantity  \
# 0      Plantronics CS510 - Over-the-Head monaural Wir...  2309.650        7
# 1              Novimex Executive Leather Armchair, Black  3709.395        9
# 2                      Nokia Smart Phone, with Caller ID  5175.171        9
# 3                         Motorola Smart Phone, Cordless  2892.510        5
# 4                         Sharp Wireless Fax, High-Speed  2832.960        8
# ...                                                  ...       ...      ...
# 51285                      Advantus Thumb Tacks, 12 Pack    65.100        5
# 51286  Hoover Replacement Belt for Commercial Guardsm...     0.444        1
# 51287       #10- 4 1/8" x 9 1/2" Security-Tint Envelopes    22.920        3
# 51288                            Acco Index Tab, Economy    13.440        2
# 51289            Eaton Computer Printout Paper, 8.5 x 11    61.380        3
#
#       Discount    Profit Shipping Cost  Order Priority  year  N_Order
# 0          0.0  762.1845       933.570        Critical  2012     9994
# 1          0.1 -288.7650       923.630        Critical  2013     2837
# 2          0.1  919.9710       915.490          Medium  2013     2837
# 3          0.1  -96.5400       910.160          Medium  2013     2065
# 4          0.0  311.5200       903.040        Critical  2013      112
# ...        ...       ...           ...             ...   ...      ...
# 51285      0.0    4.5000         0.010          Medium  2014      250
# 51286      0.8   -1.1100         0.010          Medium  2014     9994
# 51287      0.0   11.2308         0.010            High  2013     9994
# 51288      0.0    2.4000         0.003          Medium  2012     1599
# 51289      0.0    1.8000         0.002            High  2012      614
#
# [51290 rows x 25 columns]

# %%
sns.lmplot(x="CA",y="N_Order",data=df,markers="H").set(title='Relation entre le Chiffre d_affaire et le nombre de commande')

# %%
df.groupby('Product Name')['Quantity'].sum()
# Out:
# Product Name
# "While you Were Out" Message Book, One Form per Page                                                    8
# #10 Gummed Flap White Envelopes, 100/Box                                                               11
# #10 Self-Seal White Envelopes                                                                          10
# #10 White Business Envelopes,4 1/8 x 9 1/2                                                             32
# #10- 4 1/8" x 9 1/2" Recycled Envelopes                                                                37
#                                                                                                        ..
# iKross Bluetooth Portable Keyboard + Cell Phone Stand Holder + Brush for Apple iPhone 5S 5C 5, 4S 4    24
# iOttie HLCRIO102 Car Mount                                                                             12
# iOttie XL Car Mount                                                                                    14
# invisibleSHIELD by ZAGG Smudge-Free Screen Protector                                                   29
# netTALK DUO VoIP Telephone Service                                                                     26
# Name: Quantity, Length: 3788, dtype: int64

# %%
fig=px.treemap(df,path=['Product Name'],values='Quantity')
plot(fig)
# Out:
# 'temp-plot.html'

# %%
df.groupby('Category')['Quantity'].sum()
# Out:
# Category
# Furniture           34954
# Office Supplies    108182
# Technology          35176
# Name: Quantity, dtype: int64

# %%
df.groupby('Category')['Quantity'].sum().plot(kind='bar',color='y')
plt.ylabel("Quantity")
plt.title("produit vendue par catégorie")
plt.show()

# %%
df.groupby('Sub-Category')['Quantity'].sum()
# Out:
# Sub-Category
# Accessories    10946
# Appliances      6078
# Art            16301
# Binders        21429
# Bookcases       8310
# Chairs         12336
# Copiers         7454
# Envelopes       8380
# Fasteners       8390
# Furnishings    11225
# Labels          9322
# Machines        4906
# Paper          12822
# Phones         11870
# Storage        16917
# Supplies        8543
# Tables          3083
# Name: Quantity, dtype: int64

# %%
df.groupby(['Category','Sub-Category'])['Quantity'].sum()
# Out:
# Category         Sub-Category
# Furniture        Bookcases        8310
#                  Chairs          12336
#                  Furnishings     11225
#                  Tables           3083
# Office Supplies  Appliances       6078
#                  Art             16301
#                  Binders         21429
#                  Envelopes        8380
#                  Fasteners        8390
#                  Labels           9322
#                  Paper           12822
#                  Storage         16917
#                  Supplies         8543
# Technology       Accessories     10946
#                  Copiers          7454
#                  Machines         4906
#                  Phones          11870
# Name: Quantity, dtype: int64

# %%
df.groupby('Sub-Category')['Quantity'].sum().plot(kind='bar',color='m')
plt.ylabel("Quantity")
plt.title("produit vendue par sub-catégorie")
plt.show()

# %%
df.groupby('Sub-Category')['Profit'].sum()
# Out:
# Sub-Category
# Accessories    129626.30620
# Appliances     141680.58940
# Art             57953.91090
# Binders         72449.84600
# Bookcases      161924.41950
# Chairs         140396.26750
# Copiers        258567.54818
# Envelopes       29601.11630
# Fasteners       11525.42410
# Furnishings     46967.42550
# Labels          15010.51200
# Machines        58867.87300
# Paper           59207.68270
# Phones         216717.00580
# Storage        108461.48980
# Supplies        22583.26310
# Tables         -64083.38870
# Name: Profit, dtype: float64

# %%
df.groupby('Sub-Category')['Profit'].sum().plot(kind='bar',color='#A98307')
plt.ylabel("Profit")
plt.title("Profit par sub-catégorie")
plt.show()

# %%
df.groupby('Segment')['Segment'].count().plot(kind='bar',color='#D9603B')
plt.ylabel("Quantity")
plt.title("Quantity vendue par segment de client")
plt.show()

# %%
sns.distplot(df.groupby('Country')['Sales'].sum(),kde=True,hist=True,color='r')
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
# <AxesSubplot:xlabel='Sales', ylabel='Density'>

# %%
sns.distplot(df.groupby('Country')['Sales'].sum(),rug=True,hist=True,color='y')
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2103: FutureWarning:
#
# The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
# <AxesSubplot:xlabel='Sales', ylabel='Density'>

# %%
sns.distplot(df.groupby('Country')['Profit'].sum(),kde=True,hist=True,color='b')
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
# <AxesSubplot:xlabel='Profit', ylabel='Density'>

# %%
sns.distplot(df.groupby('Country')['Profit'].sum(),rug=True,color='g')
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2103: FutureWarning:
#
# The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
# <AxesSubplot:xlabel='Profit', ylabel='Density'>

# %%
sns.kdeplot(df.groupby('Country')['Profit'].sum(),color='#DD985C').set(title='densité de Profit')
# Out:
# [Text(0.5, 1.0, 'densité de Profit')]

# %%
sns.kdeplot(df.groupby('Country')['Sales'].sum(),color='#293133').set(title='densité de chiffre d_affaire')
# Out:
# [Text(0.5, 1.0, 'densité de chiffre d_affaire')]

# %%
fig=px.treemap(df,path=['Country'],values='Shipping Cost')
plot(fig)
# Out:
# 'temp-plot.html'

# %%
sns.kdeplot(df.groupby('Country')['Sales'].sum(),df.groupby('Country')['Profit'].sum(),color='g')
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# <AxesSubplot:xlabel='Sales', ylabel='Profit'>

# %%
sns.jointplot(x=df.groupby('Country')['Sales'].sum(),y=df.groupby('Country')['Profit'].sum(),kind="reg",color='r')

# %%
sns.jointplot(x=df.groupby('Country')['Sales'].sum(),y=df.groupby('Country')['Profit'].sum(),kind="kde",color="green")

# %%
sns.jointplot(x=df.groupby('Country')['Sales'].sum(),y=df.groupby('Country')['Profit'].sum(),kind="hex",color="blue")

# %%
corr=df[["Sales","Quantity","Discount","Profit","Shipping Cost"]].corr()
sns.heatmap(corr,annot=True).set(title='influence des paramétres')
# Out:
# [Text(0.5, 1.0, 'influence des paramétres')]

# %%
g=sns.PairGrid(df[["CA","Profit_pays",]],diag_sharey=False)
g.map_upper(sns.scatterplot)
g.map_lower(sns.kdeplot)
g.map_diag(sns.kdeplot)
